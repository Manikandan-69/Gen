# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\manikandan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\manikandan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\users\manikandan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\manikandan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\manikandan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\manikandan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click->nltk) (0.4.6)
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: C:\Users\ManiKandan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
corpus="""Hi Buddy. How are you? Happy to see you after a long time !. 
I am fine Mate. How are you too?
"""

# %%
print(corpus)
# Out:
# Hi Buddy. How are you? Happy to see you after a long time !.
# I am fine Mate. How are you too?

# %%
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(corpus)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sent_tokenize(corpus)
#
# File c:\Users\ManiKandan\anaconda3\Lib\site-packages\nltk\tokenize\__init__.py:106, in sent_tokenize(text, language)
#      96 def sent_tokenize(text, language="english"):
#      97     """
#      98     Return a sentence-tokenized copy of *text*,
#      99     using NLTK's recommended sentence tokenizer
#    (...)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#
# File c:\Users\ManiKandan\anaconda3\Lib\site-packages\nltk\data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     747     print(f"<<Loading {resource_url}>>")
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#     753     resource_val = opened_resource.read()
#
# File c:\Users\ManiKandan\anaconda3\Lib\site-packages\nltk\data.py:876, in _open(resource_url)
#     873 protocol, path_ = split_resource_url(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# --> 876     return find(path_, path + [""]).open()
#     877 elif protocol.lower() == "file":
#     878     # urllib might not use mode='rb', so handle this one ourselves:
#     879     return find(path_, [""]).open()
#
# File c:\Users\ManiKandan\anaconda3\Lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/english.pickle
#
#   Searched in:
#     - 'C:\\Users\\ManiKandan/nltk_data'
#     - 'c:\\Users\\ManiKandan\\anaconda3\\nltk_data'
#     - 'c:\\Users\\ManiKandan\\anaconda3\\share\\nltk_data'
#     - 'c:\\Users\\ManiKandan\\anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\ManiKandan\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - ''
# **********************************************************************

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ManiKandan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
## Tokenization
## converting paragraph --> sentences

# %%
from nltk.tokenize import sent_tokenize
# Out:
# ['Hi Buddy.',
#  'How are you?',
#  'Happy to see you after a long time !.',
#  'I am fine Mate.',
#  'How are you too?']

# %%
document=sent_tokenize(corpus)

# %%
document
# Out:
# ['Hi Buddy.',
#  'How are you?',
#  'Happy to see you after a long time !.',
#  'I am fine Mate.',
#  'How are you too?']

# %%
print(type(document))
# Out:
# <class 'list'>

# %%
for doc in document:
    print(doc)
# Out:
# Hi Buddy.
# How are you?
# Happy to see you after a long time !.
# I am fine Mate.
# How are you too?

# %%
## Tokenization
## paragarah --> words
## sentence  --> words

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hi',
#  'Buddy',
#  '.',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Happy',
#  'to',
#  'see',
#  'you',
#  'after',
#  'a',
#  'long',
#  'time',
#  '!',
#  '.',
#  'I',
#  'am',
#  'fine',
#  'Mate',
#  '.',
#  'How',
#  'are',
#  'you',
#  'too',
#  '?']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hi',
#  'Buddy',
#  '.',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Happy',
#  'to',
#  'see',
#  'you',
#  'after',
#  'a',
#  'long',
#  'time',
#  '!.',
#  'I',
#  'am',
#  'fine',
#  'Mate',
#  '.',
#  'How',
#  'are',
#  'you',
#  'too',
#  '?']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
token= TreebankWordTokenizer()

# %%
token.tokenize(corpus)
# Out:
# ['Hi',
#  'Buddy.',
#  'How',
#  'are',
#  'you',
#  '?',
#  'Happy',
#  'to',
#  'see',
#  'you',
#  'after',
#  'a',
#  'long',
#  'time',
#  '!',
#  '.',
#  'I',
#  'am',
#  'fine',
#  'Mate.',
#  'How',
#  'are',
#  'you',
#  'too',
#  '?']
