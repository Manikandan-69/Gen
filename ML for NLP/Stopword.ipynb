# %%
paragraph = """ While there were many significant events during my tenure, a question from a little girl Anukriti of Sri Sathya Sai Jagriti Vidya Mandir School, of Darwa village from Haryana, during children?s visit to Rashtrapati Bhavan on May 22, 2006, rings in my mind ever after.
Anukriti asked me ?why India cannot become a developed nation before the year 2020?. I appreciated the question and said it was indeed a thoughtful question and assured her that that her dream would be taken to the highest institution of the nation and we would work for it to achieve before 2020. This question reflects how the desire to live in developed India has entered into the minds of the youth. The same feelings are echoed by over fifteen lakh youth, whom I have met so far and who represent the dream of the 540 million youth of the nation. The aspirations of the young to live in a prosperous, safe and proud India should be the guiding factor in whatever profession we contribute.
On the evening of February 24, 2007, at Coimbatore, I had a very beautiful experience. As I got ready for meeting the first person out of twenty appointments, a wheel chair was in sight with a smiling person probably in his late fifties; unfortunately he has no hands and legs. His radiant face was revealing his happy state of mind. He introduced himself as Vidwan Coimbatore SR Krishna Murthy. I greeted him and asked him how this had happened. He smilingly said that it was from by birth. He thanked God, his parents, teachers and many others for giving him confidence, training and help. I asked him, what I could do for him? He said, ?I don?t need anything from you. I would like to sing in front of you?. I readily agreed. He sang melodiously the Saint Thyagraja?s pancha ratna kriti entharo mahanubavulu in Sriragam giving me a glimpse of his talent. I was quite touched. What is the message? Despite being physically challenged, the latent talent of music could blossom in this person with his positive attitude and perseverance, encouraged by the parents, teachers, academics and rasikas. Now he wants to give, give and give his art to inspire others. Of course, by his merit of music, in July 2007, he performed in the Rashtrapati Bhavan art theatre."""

# %%
## Apply sent_tokenize to split the paragrapgh into sentences
from nltk.tokenize import sent_tokenize

# %%
para2senetences = sent_tokenize(paragraph)

# %%
print(para2senetences)
# Out:
# [' While there were many significant events during my tenure, a question from a little girl Anukriti of Sri Sathya Sai Jagriti Vidya Mandir School, of Darwa village from Haryana, during children?s visit to Rashtrapati Bhavan on May 22, 2006, rings in my mind ever after.', 'Anukriti asked me ?why India cannot become a developed nation before the year 2020?.', 'I appreciated the question and said it was indeed a thoughtful question and assured her that that her dream would be taken to the highest institution of the nation and we would work for it to achieve before 2020.', 'This question reflects how the desire to live in developed India has entered into the minds of the youth.', 'The same feelings are echoed by over fifteen lakh youth, whom I have met so far and who represent the dream of the 540 million youth of the nation.', 'The aspirations of the young to live in a prosperous, safe and proud India should be the guiding factor in whatever profession we contribute.', 'On the evening of February 24, 2007, at Coimbatore, I had a very beautiful experience.', 'As I got ready for meeting the first person out of twenty appointments, a wheel chair was in sight with a smiling person probably in his late fifties; unfortunately he has no hands and legs.', 'His radiant face was revealing his happy state of mind.', 'He introduced himself as Vidwan Coimbatore SR Krishna Murthy.', 'I greeted him and asked him how this had happened.', 'He smilingly said that it was from by birth.', 'He thanked God, his parents, teachers and many others for giving him confidence, training and help.', 'I asked him, what I could do for him?', 'He said, ?I don?t need anything from you.', 'I would like to sing in front of you?.', 'I readily agreed.', 'He sang melodiously the Saint Thyagraja?s pancha ratna kriti entharo mahanubavulu in Sriragam giving me a glimpse of his talent.', 'I was quite touched.', 'What is the message?', 'Despite being physically challenged, the latent talent of music could blossom in this person with his positive attitude and perseverance, encouraged by the parents, teachers, academics and rasikas.', 'Now he wants to give, give and give his art to inspire others.', 'Of course, by his merit of music, in July 2007, he performed in the Rashtrapati Bhavan art theatre.']

# %%
## Apply word_tokenize to split sentence into each words
from nltk.tokenize import word_tokenize

# %%
len(para2senetences)
# Out:
# 23

# %%
para2senetences[0]
# Out:
# ' While there were many significant events during my tenure, a question from a little girl Anukriti of Sri Sathya Sai Jagriti Vidya Mandir School, of Darwa village from Haryana, during children?s visit to Rashtrapati Bhavan on May 22, 2006, rings in my mind ever after.'

# %%
para2senetences[-2]
# Out:
# 'Now he wants to give, give and give his art to inspire others.'

# %%
for i in range (len(para2senetences)):
    sent2words=word_tokenize(para2senetences[i])
    print(sent2words)
# Out:
# ['While', 'there', 'were', 'many', 'significant', 'events', 'during', 'my', 'tenure', ',', 'a', 'question', 'from', 'a', 'little', 'girl', 'Anukriti', 'of', 'Sri', 'Sathya', 'Sai', 'Jagriti', 'Vidya', 'Mandir', 'School', ',', 'of', 'Darwa', 'village', 'from', 'Haryana', ',', 'during', 'children', '?', 's', 'visit', 'to', 'Rashtrapati', 'Bhavan', 'on', 'May', '22', ',', '2006', ',', 'rings', 'in', 'my', 'mind', 'ever', 'after', '.']
# ['Anukriti', 'asked', 'me', '?', 'why', 'India', 'can', 'not', 'become', 'a', 'developed', 'nation', 'before', 'the', 'year', '2020', '?', '.']
# ['I', 'appreciated', 'the', 'question', 'and', 'said', 'it', 'was', 'indeed', 'a', 'thoughtful', 'question', 'and', 'assured', 'her', 'that', 'that', 'her', 'dream', 'would', 'be', 'taken', 'to', 'the', 'highest', 'institution', 'of', 'the', 'nation', 'and', 'we', 'would', 'work', 'for', 'it', 'to', 'achieve', 'before', '2020', '.']
# ['This', 'question', 'reflects', 'how', 'the', 'desire', 'to', 'live', 'in', 'developed', 'India', 'has', 'entered', 'into', 'the', 'minds', 'of', 'the', 'youth', '.']
# ['The', 'same', 'feelings', 'are', 'echoed', 'by', 'over', 'fifteen', 'lakh', 'youth', ',', 'whom', 'I', 'have', 'met', 'so', 'far', 'and', 'who', 'represent', 'the', 'dream', 'of', 'the', '540', 'million', 'youth', 'of', 'the', 'nation', '.']
# ['The', 'aspirations', 'of', 'the', 'young', 'to', 'live', 'in', 'a', 'prosperous', ',', 'safe', 'and', 'proud', 'India', 'should', 'be', 'the', 'guiding', 'factor', 'in', 'whatever', 'profession', 'we', 'contribute', '.']
# ['On', 'the', 'evening', 'of', 'February', '24', ',', '2007', ',', 'at', 'Coimbatore', ',', 'I', 'had', 'a', 'very', 'beautiful', 'experience', '.']
# ['As', 'I', 'got', 'ready', 'for', 'meeting', 'the', 'first', 'person', 'out', 'of', 'twenty', 'appointments', ',', 'a', 'wheel', 'chair', 'was', 'in', 'sight', 'with', 'a', 'smiling', 'person', 'probably', 'in', 'his', 'late', 'fifties', ';', 'unfortunately', 'he', 'has', 'no', 'hands', 'and', 'legs', '.']
# ['His', 'radiant', 'face', 'was', 'revealing', 'his', 'happy', 'state', 'of', 'mind', '.']
# ['He', 'introduced', 'himself', 'as', 'Vidwan', 'Coimbatore', 'SR', 'Krishna', 'Murthy', '.']
# ['I', 'greeted', 'him', 'and', 'asked', 'him', 'how', 'this', 'had', 'happened', '.']
# ['He', 'smilingly', 'said', 'that', 'it', 'was', 'from', 'by', 'birth', '.']
# ['He', 'thanked', 'God', ',', 'his', 'parents', ',', 'teachers', 'and', 'many', 'others', 'for', 'giving', 'him', 'confidence', ',', 'training', 'and', 'help', '.']
# ['I', 'asked', 'him', ',', 'what', 'I', 'could', 'do', 'for', 'him', '?']
# ['He', 'said', ',', '?', 'I', 'don', '?', 't', 'need', 'anything', 'from', 'you', '.']
# ['I', 'would', 'like', 'to', 'sing', 'in', 'front', 'of', 'you', '?', '.']
# ['I', 'readily', 'agreed', '.']
# ['He', 'sang', 'melodiously', 'the', 'Saint', 'Thyagraja', '?', 's', 'pancha', 'ratna', 'kriti', 'entharo', 'mahanubavulu', 'in', 'Sriragam', 'giving', 'me', 'a', 'glimpse', 'of', 'his', 'talent', '.']
# ['I', 'was', 'quite', 'touched', '.']
# ['What', 'is', 'the', 'message', '?']
# ['Despite', 'being', 'physically', 'challenged', ',', 'the', 'latent', 'talent', 'of', 'music', 'could', 'blossom', 'in', 'this', 'person', 'with', 'his', 'positive', 'attitude', 'and', 'perseverance', ',', 'encouraged', 'by', 'the', 'parents', ',', 'teachers', ',', 'academics', 'and', 'rasikas', '.']
# ['Now', 'he', 'wants', 'to', 'give', ',', 'give', 'and', 'give', 'his', 'art', 'to', 'inspire', 'others', '.']
# ['Of', 'course', ',', 'by', 'his', 'merit', 'of', 'music', ',', 'in', 'July', '2007', ',', 'he', 'performed', 'in', 'the', 'Rashtrapati', 'Bhavan', 'art', 'theatre', '.']

# %%
sent2words
# Out:
# ['Of',
#  'course',
#  ',',
#  'by',
#  'his',
#  'merit',
#  'of',
#  'music',
#  ',',
#  'in',
#  'July',
#  '2007',
#  ',',
#  'he',
#  'performed',
#  'in',
#  'the',
#  'Rashtrapati',
#  'Bhavan',
#  'art',
#  'theatre',
#  '.']

# %%
##Apply  stopwords and apply filter the words which not in stopwords corpus.

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
for word in sent2words:
    print(word)
# Out:
# Of
# course
# ,
# by
# his
# merit
# of
# music
# ,
# in
# July
# 2007
# ,
# he
# performed
# in
# the
# Rashtrapati
# Bhavan
# art
# theatre
# .

# %%
from nltk.stem import PorterStemmer
port_stem=PorterStemmer()

# %%
for i in range (len(para2senetences)):
    sent2words=word_tokenize(para2senetences[i])
    word_stem=[port_stem.stem(word) for word in sent2words if word not in set(stopwords.words('english'))]
    print(word_stem)
# Out:
# ['while', 'mani', 'signific', 'event', 'tenur', ',', 'question', 'littl', 'girl', 'anukr', 'sri', 'sathya', 'sai', 'jagriti', 'vidya', 'mandir', 'school', ',', 'darwa', 'villag', 'haryana', ',', 'children', '?', 'visit', 'rashtrapati', 'bhavan', 'may', '22', ',', '2006', ',', 'ring', 'mind', 'ever', '.']
# ['anukr', 'ask', '?', 'india', 'becom', 'develop', 'nation', 'year', '2020', '?', '.']
# ['i', 'appreci', 'question', 'said', 'inde', 'thought', 'question', 'assur', 'dream', 'would', 'taken', 'highest', 'institut', 'nation', 'would', 'work', 'achiev', '2020', '.']
# ['thi', 'question', 'reflect', 'desir', 'live', 'develop', 'india', 'enter', 'mind', 'youth', '.']
# ['the', 'feel', 'echo', 'fifteen', 'lakh', 'youth', ',', 'i', 'met', 'far', 'repres', 'dream', '540', 'million', 'youth', 'nation', '.']
# ['the', 'aspir', 'young', 'live', 'prosper', ',', 'safe', 'proud', 'india', 'guid', 'factor', 'whatev', 'profess', 'contribut', '.']
# ['on', 'even', 'februari', '24', ',', '2007', ',', 'coimbator', ',', 'i', 'beauti', 'experi', '.']
# ['as', 'i', 'got', 'readi', 'meet', 'first', 'person', 'twenti', 'appoint', ',', 'wheel', 'chair', 'sight', 'smile', 'person', 'probabl', 'late', 'fifti', ';', 'unfortun', 'hand', 'leg', '.']
# ['hi', 'radiant', 'face', 'reveal', 'happi', 'state', 'mind', '.']
# ['he', 'introduc', 'vidwan', 'coimbator', 'sr', 'krishna', 'murthi', '.']
# ['i', 'greet', 'ask', 'happen', '.']
# ['he', 'smilingli', 'said', 'birth', '.']
# ['he', 'thank', 'god', ',', 'parent', ',', 'teacher', 'mani', 'other', 'give', 'confid', ',', 'train', 'help', '.']
# ['i', 'ask', ',', 'i', 'could', '?']
# ['he', 'said', ',', '?', 'i', '?', 'need', 'anyth', '.']
# ['i', 'would', 'like', 'sing', 'front', '?', '.']
# ['i', 'readili', 'agre', '.']
# ['he', 'sang', 'melodi', 'saint', 'thyagraja', '?', 'pancha', 'ratna', 'kriti', 'entharo', 'mahanubavulu', 'sriragam', 'give', 'glimps', 'talent', '.']
# ['i', 'quit', 'touch', '.']
# ['what', 'messag', '?']
# ['despit', 'physic', 'challeng', ',', 'latent', 'talent', 'music', 'could', 'blossom', 'person', 'posit', 'attitud', 'persever', ',', 'encourag', 'parent', ',', 'teacher', ',', 'academ', 'rasika', '.']
# ['now', 'want', 'give', ',', 'give', 'give', 'art', 'inspir', 'other', '.']
# ['of', 'cours', ',', 'merit', 'music', ',', 'juli', '2007', ',', 'perform', 'rashtrapati', 'bhavan', 'art', 'theatr', '.']

# %%
from nltk.stem import SnowballStemmer
snow_stem=SnowballStemmer('english')

# %%
for i in range(len(para2senetences)):
    sent2words=word_tokenize(para2senetences[i])
    word_snowstem=[snow_stem.stem(word) for word in sent2words if word not in set (stopwords.words('english'))]
    print(word_snowstem)
# Out:
# ['while', 'mani', 'signific', 'event', 'tenur', ',', 'question', 'littl', 'girl', 'anukr', 'sri', 'sathya', 'sai', 'jagriti', 'vidya', 'mandir', 'school', ',', 'darwa', 'villag', 'haryana', ',', 'children', '?', 'visit', 'rashtrapati', 'bhavan', 'may', '22', ',', '2006', ',', 'ring', 'mind', 'ever', '.']
# ['anukr', 'ask', '?', 'india', 'becom', 'develop', 'nation', 'year', '2020', '?', '.']
# ['i', 'appreci', 'question', 'said', 'inde', 'thought', 'question', 'assur', 'dream', 'would', 'taken', 'highest', 'institut', 'nation', 'would', 'work', 'achiev', '2020', '.']
# ['this', 'question', 'reflect', 'desir', 'live', 'develop', 'india', 'enter', 'mind', 'youth', '.']
# ['the', 'feel', 'echo', 'fifteen', 'lakh', 'youth', ',', 'i', 'met', 'far', 'repres', 'dream', '540', 'million', 'youth', 'nation', '.']
# ['the', 'aspir', 'young', 'live', 'prosper', ',', 'safe', 'proud', 'india', 'guid', 'factor', 'whatev', 'profess', 'contribut', '.']
# ['on', 'even', 'februari', '24', ',', '2007', ',', 'coimbator', ',', 'i', 'beauti', 'experi', '.']
# ['as', 'i', 'got', 'readi', 'meet', 'first', 'person', 'twenti', 'appoint', ',', 'wheel', 'chair', 'sight', 'smile', 'person', 'probabl', 'late', 'fifti', ';', 'unfortun', 'hand', 'leg', '.']
# ['his', 'radiant', 'face', 'reveal', 'happi', 'state', 'mind', '.']
# ['he', 'introduc', 'vidwan', 'coimbator', 'sr', 'krishna', 'murthi', '.']
# ['i', 'greet', 'ask', 'happen', '.']
# ['he', 'smile', 'said', 'birth', '.']
# ['he', 'thank', 'god', ',', 'parent', ',', 'teacher', 'mani', 'other', 'give', 'confid', ',', 'train', 'help', '.']
# ['i', 'ask', ',', 'i', 'could', '?']
# ['he', 'said', ',', '?', 'i', '?', 'need', 'anyth', '.']
# ['i', 'would', 'like', 'sing', 'front', '?', '.']
# ['i', 'readili', 'agre', '.']
# ['he', 'sang', 'melodi', 'saint', 'thyagraja', '?', 'pancha', 'ratna', 'kriti', 'entharo', 'mahanubavulu', 'sriragam', 'give', 'glimps', 'talent', '.']
# ['i', 'quit', 'touch', '.']
# ['what', 'messag', '?']
# ['despit', 'physic', 'challeng', ',', 'latent', 'talent', 'music', 'could', 'blossom', 'person', 'posit', 'attitud', 'persever', ',', 'encourag', 'parent', ',', 'teacher', ',', 'academ', 'rasika', '.']
# ['now', 'want', 'give', ',', 'give', 'give', 'art', 'inspir', 'other', '.']
# ['of', 'cours', ',', 'merit', 'music', ',', 'juli', '2007', ',', 'perform', 'rashtrapati', 'bhavan', 'art', 'theatr', '.']

# %%
from nltk.stem import WordNetLemmatizer
word_lemma=WordNetLemmatizer()

# %%
for i in range(len(para2senetences)):
    sent2words=word_tokenize(para2senetences[i])
    word_afterlemma=[word_lemma.lemmatize(word) for word in sent2words if word not in set(stopwords.words('english'))]
    print(word_afterlemma)
# Out:
# ['While', 'many', 'significant', 'event', 'tenure', ',', 'question', 'little', 'girl', 'Anukriti', 'Sri', 'Sathya', 'Sai', 'Jagriti', 'Vidya', 'Mandir', 'School', ',', 'Darwa', 'village', 'Haryana', ',', 'child', '?', 'visit', 'Rashtrapati', 'Bhavan', 'May', '22', ',', '2006', ',', 'ring', 'mind', 'ever', '.']
# ['Anukriti', 'asked', '?', 'India', 'become', 'developed', 'nation', 'year', '2020', '?', '.']
# ['I', 'appreciated', 'question', 'said', 'indeed', 'thoughtful', 'question', 'assured', 'dream', 'would', 'taken', 'highest', 'institution', 'nation', 'would', 'work', 'achieve', '2020', '.']
# ['This', 'question', 'reflects', 'desire', 'live', 'developed', 'India', 'entered', 'mind', 'youth', '.']
# ['The', 'feeling', 'echoed', 'fifteen', 'lakh', 'youth', ',', 'I', 'met', 'far', 'represent', 'dream', '540', 'million', 'youth', 'nation', '.']
# ['The', 'aspiration', 'young', 'live', 'prosperous', ',', 'safe', 'proud', 'India', 'guiding', 'factor', 'whatever', 'profession', 'contribute', '.']
# ['On', 'evening', 'February', '24', ',', '2007', ',', 'Coimbatore', ',', 'I', 'beautiful', 'experience', '.']
# ['As', 'I', 'got', 'ready', 'meeting', 'first', 'person', 'twenty', 'appointment', ',', 'wheel', 'chair', 'sight', 'smiling', 'person', 'probably', 'late', 'fifty', ';', 'unfortunately', 'hand', 'leg', '.']
# ['His', 'radiant', 'face', 'revealing', 'happy', 'state', 'mind', '.']
# ['He', 'introduced', 'Vidwan', 'Coimbatore', 'SR', 'Krishna', 'Murthy', '.']
# ['I', 'greeted', 'asked', 'happened', '.']
# ['He', 'smilingly', 'said', 'birth', '.']
# ['He', 'thanked', 'God', ',', 'parent', ',', 'teacher', 'many', 'others', 'giving', 'confidence', ',', 'training', 'help', '.']
# ['I', 'asked', ',', 'I', 'could', '?']
# ['He', 'said', ',', '?', 'I', '?', 'need', 'anything', '.']
# ['I', 'would', 'like', 'sing', 'front', '?', '.']
# ['I', 'readily', 'agreed', '.']
# ['He', 'sang', 'melodiously', 'Saint', 'Thyagraja', '?', 'pancha', 'ratna', 'kriti', 'entharo', 'mahanubavulu', 'Sriragam', 'giving', 'glimpse', 'talent', '.']
# ['I', 'quite', 'touched', '.']
# ['What', 'message', '?']
# ['Despite', 'physically', 'challenged', ',', 'latent', 'talent', 'music', 'could', 'blossom', 'person', 'positive', 'attitude', 'perseverance', ',', 'encouraged', 'parent', ',', 'teacher', ',', 'academic', 'rasikas', '.']
# ['Now', 'want', 'give', ',', 'give', 'give', 'art', 'inspire', 'others', '.']
# ['Of', 'course', ',', 'merit', 'music', ',', 'July', '2007', ',', 'performed', 'Rashtrapati', 'Bhavan', 'art', 'theatre', '.']

# %%
for i in range(len(para2senetences)):
    sent2words=word_tokenize(para2senetences[i])
    word_afterlemma=[word_lemma.lemmatize(word,pos='v') for word in sent2words if word not in set(stopwords.words('english'))]
    word2sent=' '.join(word_afterlemma)
    print(word2sent)
# Out:
# While many significant events tenure , question little girl Anukriti Sri Sathya Sai Jagriti Vidya Mandir School , Darwa village Haryana , children ? visit Rashtrapati Bhavan May 22 , 2006 , ring mind ever .
# Anukriti ask ? India become develop nation year 2020 ? .
# I appreciate question say indeed thoughtful question assure dream would take highest institution nation would work achieve 2020 .
# This question reflect desire live develop India enter mind youth .
# The feel echo fifteen lakh youth , I meet far represent dream 540 million youth nation .
# The aspirations young live prosperous , safe proud India guide factor whatever profession contribute .
# On even February 24 , 2007 , Coimbatore , I beautiful experience .
# As I get ready meet first person twenty appointments , wheel chair sight smile person probably late fifties ; unfortunately hand legs .
# His radiant face reveal happy state mind .
# He introduce Vidwan Coimbatore SR Krishna Murthy .
# I greet ask happen .
# He smilingly say birth .
# He thank God , parent , teachers many others give confidence , train help .
# I ask , I could ?
# He say , ? I ? need anything .
# I would like sing front ? .
# I readily agree .
# He sing melodiously Saint Thyagraja ? pancha ratna kriti entharo mahanubavulu Sriragam give glimpse talent .
# I quite touch .
# What message ?
# Despite physically challenge , latent talent music could blossom person positive attitude perseverance , encourage parent , teachers , academics rasikas .
# Now want give , give give art inspire others .
# Of course , merit music , July 2007 , perform Rashtrapati Bhavan art theatre .

# %%
##Notes:
### WordNet Lemmatize class with the parameter pos='v' gives the best root word compared with other stemming technic.

# %%
##Step by Step process to get a root word
"""
1) convert the paragraph into sentence by using sent_tokenize
2) Convert the sentence into words by using word_tokenize
3) Before apply stemming technic to each word, filter and remove the stopwords from the words by using from nltk.corpus import stopwords.words('english')
4) Now apply all the stemming technics like Porter stemmer, Regexp stemmer ,SnowBall stemmer, Wordnet Lemmatization  to get the root word
"""
# Out:
# "\n1) convert the paragraph into sentence by using sent_tokenize\n2) Convert the sentence into words by using word_tokenize\n3) Before apply stemming technic to each word, filter and remove the stopwords from the words by using from nltk.corpus import stopwords.words('english')\n4) Now apply all the stemming technics like Porter stemmer, Regexp stemmer ,SnowBall stemmer, Wordnet Lemmatization  to get the root word\n"
